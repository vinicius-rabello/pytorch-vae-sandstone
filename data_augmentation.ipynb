# %%
import porespy as ps
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm

# %%
img_paths = os.listdir('dataset/0')
dataset = []
for path in img_paths:
    img = cv2.imread('dataset/0/' + path)

# %%
plt.imshow(img)
